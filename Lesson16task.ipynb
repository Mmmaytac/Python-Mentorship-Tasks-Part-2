# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn import metrics

# %%
data = pd.read_csv(r'C:\Users\hp\Downloads\data analitika dersler ve tasklar\lesson16\Income_happiness.csv')
data.head()
# Out:
#      income  happiness
# 0  3.862647   2.314489
# 1  4.979381   3.433490
# 2  4.923957   4.599373
# 3  3.214372   2.791114
# 4  7.196409   5.596398

# %% [markdown]
# **1. Generate Statistical Summary**
#
# **2. Data Visualization:**
# Create scatter plots to visualize the relationship between income and happiness.
# Use boxplots to visualize the distribution of income and happiness separately.
# Data Preparation:
#
# **3. Separate the income (feature) and happiness (target) data.**
# Split the data into training and testing sets (80% training, 20% testing).
#
# **4. Model Training:**
# Train a linear regression model using the training data.
# Display the model’s coefficient and intercept.
#
# **5. Model Visualization:**
# Plot the linear regression line on the scatter plot of income vs. happiness.
#
# **6. Model Evaluation:**
# Use the trained model to predict happiness on the test data.
# Evaluate the model’s performance using MAE, MSE, RMSE, and R² score.
# Compare the performance metrics between the training set and the test set to check for overfitting.
#
# **7. Model Deployment:**
# Deploy the model to predict happiness for a new set of income values.
# Display the predicted happiness values alongside the new income data.

# %%
data.describe()
# Out:
#            income   happiness
# count  498.000000  498.000000
# mean     4.466902    3.392859
# std      1.737527    1.432813
# min      1.506275    0.266044
# 25%      3.006256    2.265864
# 50%      4.423710    3.472536
# 75%      5.991913    4.502621
# max      7.481521    6.863388

# %%
plt.scatter(data['income'], data['happiness'])
plt.show()

# %%
sns.boxplot(x=data['income'])
# Out:
# <Axes: xlabel='income'>

# %%
data
# Out:
#        income  happiness
# 0    3.862647   2.314489
# 1    4.979381   3.433490
# 2    4.923957   4.599373
# 3    3.214372   2.791114
# 4    7.196409   5.596398
# ..        ...        ...
# 493  5.249209   4.568705
# 494  3.471799   2.535002
# 495  6.087610   4.397451
# 496  3.440847   2.070664
# 497  4.530545   3.710193
#
# [498 rows x 2 columns]

# %%
x=data[['income']]
y=data['happiness']

# %%
X_train, X_test, y_train, y_test= train_test_split(x,y,test_size=0.2, random_state=42)

# %%
reg=LinearRegression()
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([0.7247687])

# %%
reg.intercept_
# Out:
# np.float64(0.14170387227353531)

# %%
plt.scatter(x,y)
yhat=reg.coef_*x+reg.intercept_
fig=plt.plot(x,yhat,c='red')
plt.show()

# %%
y_pred=reg.predict(X_test)

# %%
X_test["actual_h"]=y_test
X_test['pred_h']=y_pred

X_test
# Out:
#        income  actual_h    pred_h
# 487  4.243873  4.754168  3.217530
# 73   2.864664  4.159609  2.217923
# 231  4.223554  2.295700  3.202803
# 175  2.274523  2.311554  1.790207
# 237  2.210696  2.861274  1.743947
# ..        ...       ...       ...
# 247  5.964058  3.427723  4.464266
# 383  4.851314  3.835578  3.657784
# 19   1.994275  2.584729  1.587092
# 321  4.800344  2.842868  3.620843
# 331  6.250302  4.939259  4.671727
#
# [100 rows x 3 columns]

# %%
mae=metrics.mean_absolute_error(y_test,y_pred)
mae
# Out:
# 0.6269683431894553

# %%
mse=metrics.mean_squared_error(y_test,y_pred)
mse
# Out:
# 0.590146394343082

# %%
rmse=np.sqrt(mse)
rmse
# Out:
# np.float64(0.768209863476825)

# %%
r2=metrics.r2_score(y_test,y_pred)
r2
# Out:
# 0.6662585264303965
