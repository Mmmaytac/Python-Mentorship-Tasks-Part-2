# %% [markdown]
# # Task1
# - Show 3000 random points in the rectangle ((0, 1), (0,1)).

# %% [markdown]
# # Task2
#
# Load this Broadway Musicals dataset.
#
# a. Take only “The Lion King” shows, and plot the scatter of the show run,
#    using date as the x axis and statistics gross as y axis.
#
# b. Color the previous plot by Statistics Gross Potential.
#
# c. Show a scatter describing for each theater:
#
#     i. The total # of show runs in that theater
#     ii. The average statistics gross of runs in the theater
#     iii. The capacity size (# max size)
#     iv. The min attendance of shows in the theater
